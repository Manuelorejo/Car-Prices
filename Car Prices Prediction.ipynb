# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("C:\\Users\\Oreoluwa\\Desktop\\Car Prices\CarPrice_Assignment.csv")

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df['CarName']
# Out:
# 0            alfa-romero giulia
# 1           alfa-romero stelvio
# 2      alfa-romero Quadrifoglio
# 3                   audi 100 ls
# 4                    audi 100ls
#                  ...
# 200             volvo 145e (sw)
# 201                 volvo 144ea
# 202                 volvo 244dl
# 203                   volvo 246
# 204                 volvo 264gl
# Name: CarName, Length: 205, dtype: object

# %%
def company(carname):
    new = carname.split(" ")[0]
    return new

# %%
df['Company'] = df['CarName'].apply(lambda x: company(x))

# %%
df['Company'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'vokswagen', 'volkswagen', 'volvo'],
#       dtype=object)

# %% [markdown]
# The code below replaces every instance of spelling errors with the correct spelling

# %%
def replace_name(a,b):
    df.Company.replace(a,b, inplace = True)

# %%
replace_name("maxda","mazda")
replace_name("Nissan","nissan")
replace_name("porcshce","porsche")
replace_name("toyouta","toyota")
replace_name("voswagen","volkswagen")
replace_name("vw","volkswagen")

# %%
df.drop("CarName",axis = 1,inplace = True)

# %%
df.corr(numeric_only = True)
# Out:
#                     car_ID  symboling  wheelbase  carlength  carwidth  \
# car_ID            1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# boreratio         0.260064  -0.130051   0.488750   0.606454  0.559150
# stroke           -0.160824  -0.008735   0.160959   0.129533  0.182942
# compressionratio  0.150276  -0.178515   0.249786   0.158414  0.181129
# horsepower       -0.015006   0.070873   0.353294   0.552623  0.640732
# ...

# %% [markdown]
# The columns that have a significant relation with the price are the "wheelbase","carlength",carwidth", "curbweight","enginesize" and "horsepower" columns

# %%
plt.figure(figsize = (10,8))
sns.heatmap(df.corr(numeric_only = True))
# Out:
# <Axes: >

# %%
plt.figure(figsize = (15,6))

plt.subplot(1,3,1)
plt.title("Fuel type count")
sns.countplot(x = df.fueltype)


plt.subplot(1,3,2)
plt.title("Aspiration count")
sns.countplot(x = df.aspiration)

plt.subplot(1,3,3)
plt.title("doornumber")
sns.countplot(x = df.doornumber)
# Out:
# <Axes: title={'center': 'doornumber'}, xlabel='doornumber', ylabel='count'>

# %% [markdown]
# While the "fueltype" and "aspiration" columns are heavily one-sided, there is still enough data in both categories to draw inference from them

# %%
plt.figure(figsize = (20,8))

plt.subplot(1,3,1)
plt.title("Car body count")
sns.countplot(x = df.carbody)


plt.subplot(1,3,2)
plt.title("drivewheel count")
sns.countplot(x = df.drivewheel)

plt.subplot(1,3,3)
plt.title("enginelocation")
sns.countplot(x = df.enginelocation)
# Out:
# <Axes: title={'center': 'enginelocation'}, xlabel='enginelocation', ylabel='count'>

# %% [markdown]
# From this plot, we can say that the data in "enginelocation" is too one-sided to draw meaningful inference from it

# %%
plt.figure(figsize = (20,8))

plt.subplot(1,3,1)
plt.title("Engine type count")
sns.countplot(x = df.enginetype)


plt.subplot(1,3,2)
plt.title("Cylinder number")
sns.countplot(x = df.cylindernumber)

plt.subplot(1,3,3)
plt.title("fuel system countplot")
sns.countplot(x = df.fuelsystem)
# Out:
# <Axes: title={'center': 'fuel system countplot'}, xlabel='fuelsystem', ylabel='count'>

# %% [markdown]
# The following lines of code drop the unique data points in the "enginetype", "cylindernumber" and "fuelsystem" columns

# %%
df[df["fuelsystem"] == "mfi"]
# Out:
#     car_ID  symboling fueltype aspiration doornumber    carbody drivewheel  \
# 29      30          3      gas      turbo        two  hatchback        fwd
#
#    enginelocation  wheelbase  carlength  ...  fuelsystem  boreratio  stroke  \
# 29          front       95.9      173.2  ...         mfi        3.6     3.9
#
#    compressionratio horsepower  peakrpm citympg  highwaympg    price  Company
# 29              7.0        145     5000      19          24  12964.0    dodge
#
# [1 rows x 26 columns]

# %%
df.drop(29,inplace = True)

# %%
df[df["fuelsystem"] == "spfi"]
# Out:
# Empty DataFrame
# Columns: [car_ID, symboling, fueltype, aspiration, doornumber, carbody, drivewheel, enginelocation, wheelbase, carlength, carwidth, carheight, curbweight, enginetype, cylindernumber, enginesize, fuelsystem, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price, Company]
# Index: []
#
# [0 rows x 26 columns]

# %%
df.drop(46,inplace = True)

# %%
df[df['cylindernumber'] == "three"]
# Out:
#     car_ID  symboling fueltype aspiration doornumber    carbody drivewheel  \
# 18      19          2      gas        std        two  hatchback        fwd
#
#    enginelocation  wheelbase  carlength  ...  fuelsystem  boreratio  stroke  \
# 18          front       88.4      141.1  ...        2bbl       2.91    3.03
#
#    compressionratio horsepower  peakrpm citympg  highwaympg   price    Company
# 18              9.5         48     5100      47          53  5151.0  chevrolet
#
# [1 rows x 26 columns]

# %%
df.drop(18,inplace = True)

# %%
df[df['cylindernumber'] == "twelve"]
# Out:
#     car_ID  symboling fueltype aspiration doornumber carbody drivewheel  \
# 49      50          0      gas        std        two   sedan        rwd
#
#    enginelocation  wheelbase  carlength  ...  fuelsystem  boreratio  stroke  \
# 49          front      102.0      191.7  ...        mpfi       3.54    2.76
#
#    compressionratio horsepower  peakrpm citympg  highwaympg    price  Company
# 49             11.5        262     5000      13          17  36000.0   jaguar
#
# [1 rows x 26 columns]

# %%
df.drop(49,inplace = True)

# %%
df[df['enginetype'] == "dohcv"]
# Out:
#      car_ID  symboling fueltype aspiration doornumber    carbody drivewheel  \
# 129     130          1      gas        std        two  hatchback        rwd
#
#     enginelocation  wheelbase  carlength  ...  fuelsystem  boreratio  stroke  \
# 129          front       98.4      175.7  ...        mpfi       3.94    3.11
#
#     compressionratio horsepower  peakrpm citympg  highwaympg    price  Company
# 129             10.0        288     5750      17          28  31400.5  porsche
#
# [1 rows x 26 columns]

# %%
df.drop(129,inplace = True)

# %%
plt.figure(figsize = (20,8))

plt.subplot(1,3,1)
plt.title("Engine type count")
sns.boxplot(x = df.enginetype, y =df.price)


plt.subplot(1,3,2)
plt.title("Cylinder number")
sns.boxplot(x = df.cylindernumber, y =df.price)

plt.subplot(1,3,3)
plt.title("fuel system countplot")
sns.boxplot(x = df.fuelsystem, y = df.price)
# Out:
# <Axes: title={'center': 'fuel system countplot'}, xlabel='fuelsystem', ylabel='price'>

# %%
plt.figure(figsize = (20,7))


graph = pd.DataFrame(df.groupby(["Company"])["price"].mean().sort_values(ascending = False))
graph.plot.bar()
plt.title("Company Name against Average Price")
plt.show()



graph = pd.DataFrame(df.groupby(["fueltype"])["price"].mean().sort_values(ascending = False))
graph.plot.bar()
plt.title("Fuel type against Average Price")
plt.show()


graph = pd.DataFrame(df.groupby(["doornumber"])["price"].mean().sort_values(ascending = False))
graph.plot.bar()
plt.title("Number of doors against Average Price")
plt.show()

# %% [markdown]
# The Company name and fuel type have an effect on the price while the number of doors doesn't

# %%
plt.figure(figsize = (20,6))

graph = pd.DataFrame(df.groupby(["drivewheel"])["price"].mean().sort_values(ascending = False))
graph.plot.bar()
plt.title("drivewheel against Average Price")
plt.show()

graph = pd.DataFrame(df.groupby(["enginetype"])["price"].mean().sort_values(ascending = False))
graph.plot.bar()
plt.title("Engine type against Average Price")
plt.show()

# %% [markdown]
# The drivewheel and enginetype both have significant effects on the price

# %%
plt.figure(figsize = (20,6))
graph = pd.DataFrame(df.groupby(["cylindernumber"])["price"].mean().sort_values(ascending = False))
graph.plot.bar()
plt.title("Number of cylinders against Average Price")
plt.show()


graph = pd.DataFrame(df.groupby(["fuelsystem"])["price"].mean().sort_values(ascending = False))
graph.plot.bar()
plt.title("Fuel system against Average Price")
plt.show()


graph = pd.DataFrame(df.groupby(["boreratio"])["price"].mean().sort_values(ascending = False))
graph.plot.bar()
plt.title("Boreratio against Average Price")
plt.show()

# %% [markdown]
# The number of cylinders, fuelsystem and boreratio all have significant effects on the price

# %%
#Binning the Car Companies based on avg prices of each Company.
df['price'] = df['price'].astype('int')
temp = df.copy()
table = temp.groupby(['Company'])['price'].mean()
temp = temp.merge(table.reset_index(), how='left',on='Company')
bins = [0,10000,20000,40000]
df_bin=['Budget','Medium','Highend']
df['carsrange'] = pd.cut(temp['price_y'],bins,right=False,labels=cars_bin)
df.head()
# Out:
#    car_ID  symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0       1          3      gas        std        two  convertible        rwd
# 1       2          3      gas        std        two  convertible        rwd
# 2       3          1      gas        std        two    hatchback        rwd
# 3       4          2      gas        std       four        sedan        fwd
# 4       5          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  ...  boreratio  stroke  \
# 0          front       88.6      168.8  ...       3.47    2.68
# 1          front       88.6      168.8  ...       3.47    2.68
# 2          front       94.5      171.2  ...       2.68    3.47
# 3          front       99.8      176.6  ...       3.19    3.40
# 4          front       99.4      176.6  ...       3.19    3.40
#
#    compressionratio horsepower peakrpm  citympg highwaympg  price  \
# ...

# %% [markdown]
# After analysis the relevant columns are "wheelbase","carlength",carwidth", "curbweight","enginesize","horsepower", "Carsrange","fueltype","drivewheel","enginetype","cylindernumber","fuelsystem" and "boreratio" columns

# %%
cars = df[["price","wheelbase","carlength","carwidth", "curbweight","enginesize","horsepower","fueltype","drivewheel","enginetype","cylindernumber","fuelsystem","boreratio","carsrange"]]

# %%
sns.pairplot(cars)

# %%
cars['carsrange']
# Out:
# 0      Medium
# 1      Medium
# 2      Medium
# 3      Medium
# 4      Medium
#         ...
# 200       NaN
# 201       NaN
# 202       NaN
# 203       NaN
# 204       NaN
# Name: carsrange, Length: 200, dtype: category
# Categories (3, object): ['Budget' < 'Medium' < 'Highend']

# %%
def OHE(x,df):
    temp_df = pd.get_dummies(df[x],drop_first=True)
    df = pd.concat([df,temp_df], axis = 1)
    df.drop(x,axis =1, inplace = True)
    return df

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   price       200 non-null    int32
#  1   wheelbase   200 non-null    float64
#  2   carlength   200 non-null    float64
#  3   carwidth    200 non-null    float64
#  4   curbweight  200 non-null    int64
#  5   enginesize  200 non-null    int64
#  6   horsepower  200 non-null    int64
#  7   boreratio   200 non-null    float64
#  8   gas         200 non-null    uint8
#  9   fwd         200 non-null    uint8
#  10  rwd         200 non-null    uint8
#  11  l           200 non-null    uint8
#  12  ohc         200 non-null    uint8
#  13  ohcf        200 non-null    uint8
#  14  ohcv        200 non-null    uint8
#  15  rotor       200 non-null    uint8
#  16  five        200 non-null    uint8
#  17  four        200 non-null    uint8
#  18  six         200 non-null    uint8
# ...

# %%
cars = OHE("fueltype",cars)
cars = OHE("drivewheel",cars)
cars = OHE("enginetype",cars)
cars = OHE("cylindernumber",cars)
cars = OHE("fuelsystem",cars)
cars = OHE("carsrange",cars)

# %% [markdown]
# The code above replaces the categorical columns in the dataframe with their dummy variables and removes the original column

# %%
cars.drop([200,201,202,203,204],inplace = True)

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
train_data = scaler.fit_transform(cars.drop("price",axis =1 ))

# %%
X = train_data
y = cars['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=100)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score

# %%
y_pred  = model.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8432320429265925
